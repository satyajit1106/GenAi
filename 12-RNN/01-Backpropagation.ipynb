# %% [markdown]
# ### RNN
# #### BackPropagation
# ![image.png](attachment:image.png)

# %% [markdown]
# - we need back propagatoin to reduce the loss till we reach the global minima
# - in forward propagation we calculate the loss
# - in backward propagation we use the weight updation formula to reduce the loss.
# - we need to update 3 weights wi, wh, wo
#
# #### updating the Wh which is the hidden weight in one go
#  ![image.png](attachment:image.png)
#
# #### updating the Wo as the output weight
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Disadvantage of RNN
#
# - long term dependency cannout be captured by the simple RNN.
#
# ![image.png](attachment:image.png)
#
# - while finding derivative of the first word using the backpropogarion of the nodes we come to know that the word at the beguning participate less in comparision to the other word and can be negelected as it's derivative come ~ 0
#
# * this problem is called the vaninshing gradient problem, since the previous element of the sentence are playing the less role predecting the next word in the sentence.
# * to solve these problem we use the RELU and the Leaky RELU
