# %% [markdown]
# - All the RNN Models are failing to give the many to many outputs like,
# language translation, etc cannot be accomplished by the existing RNN models, so there comes the Encoder and Decoder.
#
# - Encoder:- convert word to array of number or convert to the context vector which is fed into the decoder
# - Decoder:- It generate the output word by word and keep feeding the previous word into the decoder again.

# %% [markdown]
# ![image.png](attachment:image.png)
